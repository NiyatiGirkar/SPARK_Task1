# %%
## By Niyati Girkar
## Intern at GRIP The Sparks Foundation

# %%
## Domain : Computer Vision & Internet of Things.
## Task 1 : Object Detection / Optical Character Recognisation (ORC).
## Level : Beginner.

# %%
## importing the directories
import cv2
import matplotlib.pylab as plt

# Reading pretrained models from .
config_file = "ssd_mobilenet_v3_large_coco_2020_01_14.pbtxt"
frozen_model = "frozen_inference_graph.pb"
model = cv2.dnn_DetectionModel(frozen_model, config_file)

# Reading data set from coco dataset which is already downloaded.
classNames = []
data = "coco.names.txt"
with open(data,"rt") as p:
    classNames = p.read().rstrip('\n').split(('\n'))

# We are loading the model of equation and assigning value for input size; precision scale,
# Setting the color scale and  converting it to BGR scale.
model.setInputSize(320,320)                         # Size of input model as in config model its 320*320.
model.setInputScale(1.0 / 127.5)                    # Value of white color is 255, so gray = 127.5
model.setInputMean((127.5,127.5,127.5))             # Setting mean of every color in BGR (0-255).
model.setInputSwapRB(True)                          # As for normal images its RGB and we want BGR hence swap.

# Importing image/ video from machine or from webcam.
cap = cv2.VideoCapture("video.mp4")
if not cap.isOpened():
    cap = cv2.VideoCapture(0)
if not cap.isOpened():
    raise IOError ('unable to open')


fontScale = 3
font = cv2.FONT_HERSHEY_PLAIN

# Displaying the detected box for an image and class for the same.
while True:
    ret,frame = cap.read()
    frame = cv2.resize(frame, (500,500))
    classIndex, confidance, bbox = model.detect(frame, confThreshold=0.5)
    print(classIndex)
    if (len(classIndex)!=0):
        for classInd, conf, box in zip(classIndex.flatten(), confidance.flatten(),bbox) :
            if (classInd<=80):
                cv2.rectangle(frame,box,(255,0,0),1)
                cv2.putText(frame, classNames[classInd-1].upper(),(box[0], box[0]+200),font,fontScale,(0,0,255),1)
    cv2.imshow("Output",frame)
    if cv2.waitKey(2) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyall
# Out:
# [[3]
#  [3]
#  [1]
#  [3]]
# [[3]
#  [3]
#  [1]
#  [3]]
# [[3]
#  [3]
#  [1]
#  [3]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [3]]
# [[3]
#  [3]
#  [1]
#  [3]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [3]]
# [[3]
#  [3]
#  [1]
#  [3]]
# [[3]
#  [3]
#  [1]
#  [3]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [3]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [3]]
# [[3]
#  [3]
#  [1]
#  [3]]
# [[3]
#  [3]
#  [1]
#  [3]]
# [[3]
#  [3]
#  [1]
#  [3]]
# [[3]
#  [3]
#  [1]
#  [3]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [3]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [1]
#  [3]
#  [1]]
# [[3]
#  [1]
#  [3]
#  [1]]
# [[3]
#  [1]
#  [3]
#  [1]]
# [[3]
#  [1]
#  [3]
#  [1]]
# [[3]
#  [1]
#  [3]
#  [1]]
# [[3]
#  [1]
#  [3]
#  [1]]
# [[3]
#  [1]
#  [3]
#  [1]]
# [[3]
#  [1]
#  [3]
#  [1]]
# [[3]
#  [1]
#  [3]
#  [1]]
# [[3]
#  [1]
#  [3]
#  [1]]
# [[3]
#  [1]
#  [3]
#  [1]]
# [[3]
#  [1]
#  [3]
#  [1]]
# [[3]
#  [1]
#  [3]
#  [1]]
# [[3]
#  [1]
#  [3]
#  [1]]
# [[3]
#  [1]
#  [3]
#  [1]]
# [[3]
#  [1]
#  [3]
#  [1]]
# [[3]
#  [1]
#  [3]
#  [1]]
# [[3]
#  [1]
#  [3]
#  [1]]
# [[3]
#  [1]
#  [3]
#  [1]]
# [[3]
#  [1]
#  [3]
#  [1]]
# [[3]
#  [1]
#  [3]
#  [1]]
# [[3]
#  [1]
#  [3]
#  [1]]
# [[3]
#  [1]
#  [3]
#  [1]]
# [[3]
#  [1]
#  [3]
#  [1]]
# [[3]
#  [1]
#  [3]
#  [1]]
# [[3]
#  [1]
#  [3]
#  [1]]
# [[3]
#  [1]
#  [3]
#  [1]]
# [[3]
#  [1]
#  [3]
#  [1]]
# [[3]
#  [1]
#  [3]
#  [1]]
# [[3]
#  [1]
#  [3]
#  [1]]
# [[3]
#  [1]
#  [3]]
# [[3]
#  [1]
#  [3]]
# [[3]
#  [1]
#  [3]]
# [[3]
#  [1]
#  [3]]
# [[3]
#  [1]
#  [3]]
# [[3]
#  [1]
#  [3]]
# [[3]
#  [1]
#  [3]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# [[3]
#  [3]
#  [1]]
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-10-060ac78c9b85> in <module>
#      35 while True:
#      36     ret,frame = cap.read()
# ---> 37     frame = cv2.resize(frame, (500,500))
#      38     classIndex, confidance, bbox = model.detect(frame, confThreshold=0.5)
#      39     print(classIndex)
#
# error: OpenCV(4.5.1) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-kh7iq4w7\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
